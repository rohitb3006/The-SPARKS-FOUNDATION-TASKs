# %% [markdown]
# # The Sparks Foundation
# # GRIP JANUARY 2022
# # Data Science and Business Analytics Intern
#
# # TASK 2:
# **Prediction using Unsupervised ML .
# Predict the optimum number of clusters**
#
#
# AUTHOR : ROHIT BHATIA

# %% [markdown]
# **importing the libraries**

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", color_codes=True)
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# **Importing the datset**

# %%
iris = pd.read_csv("Iris.csv") 
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# **Data preprocessing**

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris["Species"].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# **Exploratory Data Analyis**

# %%
sns.distplot(a=iris['PetalLengthCm'], kde=False)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm'>

# %% [markdown]
# This graph shows data distribution of a Petal length  against the density distribution.
# Insights : it shows 5-6cmcm  petal length  is used more

# %%
sns.kdeplot(data=iris['PetalLengthCm'], shade=True)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Density'>

# %% [markdown]
# This graph shows estimate the probability density of a Petal length  .
# Insights : it shows 5-6cm has more probability density .

# %%
sns.jointplot(x=iris['PetalLengthCm'], y=iris['SepalWidthCm'], kind="kde")

# %%
sns.jointplot(x="SepalLengthCm", y="SepalWidthCm", data=iris, size=5)

# %% [markdown]
# This joint plot represents most data consist of petal length of between 4-6 cm and with sepal width of 2.5-4

# %%
iris.plot(kind="scatter", x="SepalLengthCm", y="SepalWidthCm")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.FacetGrid(iris, hue="Species", size=5) \
   .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
   .add_legend()

# %% [markdown]
# Visualising the clusters - On the first two columns usinf facetgrid

# %%
ax = sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
ax = sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray")

# %% [markdown]
# the above graph represnts minimum, first quartile, median, third quartile, and maximum of the different species of flower with dots representing the petal lenghth of diffrent varieties of flower  .

# %%
sns.violinplot(x="Species", y="PetalLengthCm", data=iris, size=6)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.FacetGrid(iris, hue="Species", size=6) \
   .map(sns.kdeplot, "PetalLengthCm") \
   .add_legend()

# %% [markdown]
# It shows density of petal length of all the three species .

# %%
sns.pairplot(iris.drop("Id", axis=1), hue="Species", size=3)

# %% [markdown]
# Pairplot has been drawn on the basis of all the features for all diffrent species

# %% [markdown]
# Dropping the column ID  and species and putting in X which will be the features
# y is the column which is to be predicted .

# %%
X = iris.drop(['Id', 'Species'], axis=1)
y = iris['Species']
print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %% [markdown]
#  **Splitting the dataset into the Training set and Test set with test size of 40 percent**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=5)

# %% [markdown]
# **Model 1 Logistic regression**

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.9833333333333333

# %% [markdown]
# The accuracy score of Logistic regression is 98.33 %

# %% [markdown]
# **Model 2: KNN**

# %%
k_range = list(range(1,26))
scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(metrics.accuracy_score(y_test, y_pred))
    
plt.plot(k_range, scores)
plt.xlabel('Value of k for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors')
plt.show()

# %% [markdown]
# Optimal no of neighbours are 12

# %%
knn = KNeighborsClassifier(n_neighbors=12)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.9833333333333333

# %% [markdown]
# The accuracy score of KNN is 98.33 %

# %%
knn.predict([[6, 3, 4, 2]])
# Out:
# array(['Iris-versicolor'], dtype=object)

# %% [markdown]
# **Model 3 : KMeans**

# %%
from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
    
# Plotting the results onto a line graph, 
# `allowing us to observe 'The elbow'
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') # Within cluster sum of squares
plt.show()

# %% [markdown]
# # Optimum no of of clusters are : 3
